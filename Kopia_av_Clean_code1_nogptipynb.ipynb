# %%
# !pip install transformers datasets torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
#Mounting drive to load the corpus
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install datasets==1.18.0
# Out:
# Collecting datasets==1.18.0
#   Downloading datasets-1.18.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (1.26.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (17.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->datasets==1.18.0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (3.11.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==1.18.0) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==1.18.0) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.0) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.0) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.18.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.18.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.18.0) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==1.18.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==1.18.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==1.18.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==1.18.0) (1.16.0)
# Downloading datasets-1.18.0-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.3/311.3 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.1.0
#     Uninstalling datasets-3.1.0:
#       Successfully uninstalled datasets-3.1.0
# Successfully installed datasets-1.18.0

# %%
#FINETUNING BERT

# %%
#Required libraries
import json
import torch
import numpy as np
import logging
import os
from torch.utils.data import Dataset, random_split
from transformers import BertForQuestionAnswering, BertTokenizerFast, TrainingArguments, Trainer, TrainerCallback
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score


# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Load the corpus
def load_corpus(file_path):
    logger.info("Loading corpus...")
    try:
        with open(file_path, 'r') as f:
            corpus = json.load(f)
        logger.info(f"Successfully loaded corpus with {len(corpus)} documents.")
        return corpus
    except Exception as e:
        logger.error(f"Error loading corpus: {str(e)}")
        return None

# Prepare the dataset
class PEDDataset(Dataset):
    def __init__(self, corpus, tokenizer, max_length=512):
        self.examples = []
        for doc in corpus:
            context = ' '.join([section['processed_text'] for section in doc['sections']])
            for section in doc['sections']:
                if section['section']:
                    question = f"What is {section['section']}?"
                    answer = section['processed_text']

                    inputs = tokenizer.encode_plus(
                        question, context,
                        max_length=max_length,
                        truncation='only_second',
                        return_offsets_mapping=True,
                        padding='max_length',
                        return_tensors='pt'
                    )

                    input_ids = inputs['input_ids'].squeeze()
                    attention_mask = inputs['attention_mask'].squeeze()
                    offset_mapping = inputs['offset_mapping'].squeeze().tolist()

                    start_char = context.find(answer)
                    end_char = start_char + len(answer)

                    start_token, end_token = None, None
                    for idx, (start, end) in enumerate(offset_mapping):
                        if start <= start_char < end:
                            start_token = idx
                        if start < end_char <= end:
                            end_token = idx
                        if start_token is not None and end_token is not None:
                            break

                    if start_token is not None and end_token is not None:
                        self.examples.append({
                            'input_ids': input_ids,
                            'attention_mask': attention_mask,
                            'start_positions': start_token,
                            'end_positions': end_token
                        })
        logger.info(f"Created dataset with {len(self.examples)} examples.")

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        return self.examples[idx]

# Check if CUDA (GPU) is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")

# Function to compute metrics
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    start_logits, end_logits = predictions
    start_pred = np.argmax(start_logits, axis=1)
    end_pred = np.argmax(end_logits, axis=1)
    start_true, end_true = labels

    precision_start = precision_score(start_true, start_pred, average='macro', zero_division=0)
    recall_start = recall_score(start_true, start_pred, average='macro', zero_division=0)
    f1_start = f1_score(start_true, start_pred, average='macro', zero_division=0)

    precision_end = precision_score(end_true, end_pred, average='macro', zero_division=0)
    recall_end = recall_score(end_true, end_pred, average='macro', zero_division=0)
    f1_end = f1_score(end_true, end_pred, average='macro', zero_division=0)

    f1 = (f1_start + f1_end) / 2

    return {
        "precision_start": precision_start,
        "recall_start": recall_start,
        "f1_start": f1_start,
        "precision_end": precision_end,
        "recall_end": recall_end,
        "f1_end": f1_end,
        "f1": f1
    }
# Helper functions for QA
def thematic_chunking(context):
    return [section['processed_text'] for doc in corpus for section in doc['sections']]

# Function to return the top 5 passages
def filter_relevant_chunks(question, chunks, top_n=5):
    keywords = question.lower().split()
    relevant_chunks = [
        chunk for chunk in chunks if any(keyword in chunk.lower() for keyword in keywords)
    ]
    # Limit to top N passages
    return relevant_chunks[:top_n] if relevant_chunks else chunks[:top_n]

# Function to answer questions using the fine-tuned model
def answer_question(question, context, model, tokenizer):
    thematic_chunks = thematic_chunking(context)
    relevant_chunks = filter_relevant_chunks(question, thematic_chunks)

    best_answer = ""
    best_score = float("-inf")

    print(f"Relevant passages for the question '{question}':\n")
    for idx, chunk in enumerate(relevant_chunks):
        print(f"Passage {idx + 1}: {chunk}\n")

        inputs = tokenizer.encode_plus(
            question, chunk,
            max_length=512,
            truncation=True,
            return_tensors='pt'
        ).to(device)

        with torch.no_grad():
            outputs = model(**inputs)

        answer_start = torch.argmax(outputs.start_logits)
        answer_end = torch.argmax(outputs.end_logits) + 1
        answer = tokenizer.decode(inputs['input_ids'][0][answer_start:answer_end])

        score = outputs.start_logits[0, answer_start] + outputs.end_logits[0, answer_end - 1]

        if score > best_score:
            best_score = score
            best_answer = answer

    return best_answer

# Custom Trainer with epoch-wise logging of training loss
class CustomTrainer(Trainer):
    def train(self, *args, **kwargs):
        print("Starting training...")
        training_loss_per_epoch = []
        output = super().train(*args, **kwargs)
        # Append final loss logs
        if hasattr(self.state, 'log_history'):
            for log in self.state.log_history:
                if 'loss' in log:
                    training_loss_per_epoch.append(log['loss'])
        print(f"Epoch-wise training loss: {training_loss_per_epoch}")
        return output

# Callback to log loss at the end of each epoch
class LogEpochLossCallback(TrainerCallback):
    def on_epoch_end(self, args, state, control, **kwargs):
        logger.info(f"Epoch {state.epoch} completed. Loss: {state.log_history[-1].get('loss', 'Not logged')}")

# Fine-tune BERT
def train_model(train_dataset, val_dataset, model_save_path):
    model = BertForQuestionAnswering.from_pretrained('bert-base-uncased').to(device)

    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=6,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        warmup_steps=0,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_strategy="epoch",  # Log after each epoch
        evaluation_strategy="epoch",  # Evaluate after each epoch
        save_strategy="epoch",  # Save the checkpoints at each epoch
        load_best_model_at_end=True,
        report_to="none",
        learning_rate=2e-5,
        lr_scheduler_type="constant",
        logging_first_step=True
    )

    trainer = CustomTrainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics
    )

    trainer.add_callback(LogEpochLossCallback())  # Add custom callback for logging

    print("Training the model...")
    train_result = trainer.train()
    print(f"Training completed. Metrics: {train_result.metrics}")

    # Evaluate the model after training
    eval_results = trainer.evaluate()
    print(f"Evaluation results: {eval_results}")

    # Save the trained model
    model.save_pretrained(model_save_path)
    print(f"Trained model saved to {model_save_path}")

    return model, trainer

# Main execution
if __name__ == "__main__":
    # Load corpus
    corpus = load_corpus('/content/drive/MyDrive/tokenized_scopusNOGPT.json')
    if corpus is None:
        logger.error("Failed to load corpus.")
        exit()

    # Initialize tokenizer and create the  dataset
    tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
    dataset = PEDDataset(corpus, tokenizer)

    if len(dataset) == 0:
        logger.error("The dataset is empty.")
        exit()

    # Split the dataset into train and validation
    train_size = int(0.9 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    # Model saved to the path
    model_save_path = '/content/drive/MyDrive/fine_tuned_PED_modelx'
    model, trainer = train_model(train_dataset, val_dataset, model_save_path)
    # Test qns
    context = ' '.join([section['processed_text'] for doc in corpus for section in doc['sections']])
    questions = [
    "How do Positive Energy Districts contribute to urban sustainability?",
    "What is the annual renewal generation district in Umea?",
    "What are the main challenges in implementing Positive Energy Districts?",
    "How do tools and methodologies contribute to the design of positive energy districts?",
    "In what ways do PEDs integrate data-driven design principles?",
    "Why are tools for engaging multiple stakeholders essential in PED planning?",
    "What distinguishes net-zero energy buildings from positive energy districts?",
    "How do varying scales and boundary definitions influence PED analysis?",
    "What are positive energy districts?",
    "How does building envelope retrofitting in PEDs work?",
    "What are specific examples of how PEDs are implemented in Italy?"
    "What are the primary renewable energy technologies proposed for the transition to a Positive Energy District? in Riga?",
    "What is the purpose of multi-stakeholder engagement tools?",
    "What are the differences between net zero energy building and positive energy district?",
    "How do different scales and evaluation boundaries affect positive energy district analysis?",
    "What is involved in the planning of positive energy districts?",
    ]

    for question in questions:
        print(f"Question: {question}")
        print(f"Answer: {answer_question(question, context, model, tokenizer)}")
        print("\n" + "-"*50 + "\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Training the model...
# Starting training...
#     <div>
#
#       <progress value='48' max='48' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [48/48 00:55, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision Start</th>
#       <th>Recall Start</th>
#       <th>F1 Start</th>
#       <th>Precision End</th>
#       <th>Recall End</th>
#       <th>F1 End</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.751000</td>
#       <td>4.965907</td>
#       <td>0.142857</td>
#       <td>0.061224</td>
#       <td>0.085714</td>
#       <td>0.166667</td>
#       <td>0.166667</td>
#       <td>0.166667</td>
#       <td>0.126190</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.489000</td>
#       <td>3.810696</td>
#       <td>0.208333</td>
#       <td>0.178571</td>
#       <td>0.192308</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.232517</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.530100</td>
#       <td>2.818832</td>
#       <td>0.285714</td>
#       <td>0.285714</td>
#       <td>0.285714</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.279221</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.658400</td>
#       <td>1.970274</td>
#       <td>0.437500</td>
#       <td>0.500000</td>
#       <td>0.466667</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.272727</td>
#       <td>0.369697</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.014200</td>
#       <td>1.869659</td>
#       <td>0.437500</td>
#       <td>0.500000</td>
#       <td>0.466667</td>
#       <td>0.555556</td>
#       <td>0.555556</td>
#       <td>0.555556</td>
#       <td>0.511111</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.513000</td>
#       <td>1.474523</td>
#       <td>0.437500</td>
#       <td>0.500000</td>
#       <td>0.466667</td>
#       <td>0.400000</td>
#       <td>0.400000</td>
#       <td>0.400000</td>
#       <td>0.433333</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch-wise training loss: [6.3587, 5.751, 4.489, 3.5301, 2.6584, 2.0142, 1.513]
# Training completed. Metrics: {'train_runtime': 57.9281, 'train_samples_per_second': 6.629, 'train_steps_per_second': 0.829, 'total_flos': 100337954586624.0, 'train_loss': 3.3386014699935913, 'epoch': 6.0}
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Evaluation results: {'eval_loss': 1.4745231866836548, 'eval_precision_start': 0.4375, 'eval_recall_start': 0.5, 'eval_f1_start': 0.4666666666666667, 'eval_precision_end': 0.4, 'eval_recall_end': 0.4, 'eval_f1_end': 0.4, 'eval_f1': 0.43333333333333335, 'eval_runtime': 0.2819, 'eval_samples_per_second': 28.378, 'eval_steps_per_second': 3.547, 'epoch': 6.0}
# Trained model saved to /content/drive/MyDrive/fine_tuned_PED_modelx
# Question: How do Positive Energy Districts contribute to urban sustainability?
# Relevant passages for the question 'How do Positive Energy Districts contribute to urban sustainability?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------
#
# Question: What is the annual renewal generation district in Umea?
# Relevant passages for the question 'What is the annual renewal generation district in Umea?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------
#
# Question: What are the main challenges in implementing Positive Energy Districts?
# Relevant passages for the question 'What are the main challenges in implementing Positive Energy Districts?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------
#
# Question: How do tools and methodologies contribute to the design of positive energy districts?
# Relevant passages for the question 'How do tools and methodologies contribute to the design of positive energy districts?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------
#
# Question: In what ways do PEDs integrate data-driven design principles?
# Relevant passages for the question 'In what ways do PEDs integrate data-driven design principles?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# ...
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------
#
# Question: What is involved in the planning of positive energy districts?
# Relevant passages for the question 'What is involved in the planning of positive energy districts?':
#
# Passage 1: positive_energy_district expected play major role energy_transition city hence paper aims introducing novel methodology useful district energy environmental analysis intended support accomplishment targets positive_energy_district district community level proposed approach relies basic concepts underpinning baseline_emission_inventory encompasses ambitious challenging objectives characterizing positive_energy_district making proposed evaluation framework accessible many user categories possible researchers local institutions urban planners etc calculation steps transposed user friendly ready use tool called en end energy environmental analysis district applicability replicability outputs work proven energy environmental assessment reference case_study particular district analysed south italy equipped photovoltaic plants wind turbine results obtained show proposed approach may serve prove achievement positive_energy_district status guide design sustainable district based energy_system thus supporting decarbonization city
#
# Passage 2: introduction urban areas large contributors energy_consumption greenhouse_gas emissions major impact climate_change thereby building accounted european final energy_consumption greenhouse_gas emissions along transport sector building sector recognized one key responsible city carbon_dioxide emissions account total carbon_dioxide emissions global level hence sustainability city called enhanced tackle climate_change achieve carbon neutrality
#
# Passage 3: european commission launched european_union eu strategy adaptation climate_change april updated main goal support development mitigation adaption measures regional local level gradually increasing resilience climate_change europe city especially encouraged sign covenant mayors climate energy covenant mayors initiative originally launched aimed engaging local government act achieving eu targets climate energy eu targets encompassed covenant mayors climate energy took key role global covenant mayors initiative vision signatory authorities promote decarbonization city increase resilience providing sustainable affordable secure energy citizens among others main commitments • use baseline_emission_inventory bei common methodological approach measuring greenhouse_gas emissions baseline year • development sustainable energy climate_action plan secap define comprehensive set measures undertaken achieve goals set indeed groups building offer interesting opportunities speeding decarbonization urban areas
#
# Passage 4: district community oriented approaches promoted european regulatory framework achieving zero energy even challenging positive energy target positive_energy_district defined mixed use energy_efficient district net zero carbon_dioxide emissions actively manage annual local surplus production renewable_energy require interaction integration building users regional energy mobility ict system ensuring social economic environmental sustainability current future generations integrate definition distinction autonomous dynamic virtual candidate positive_energy_district must recalled deployment positive_energy_district expected significantly improve sustainability urban energy_system european positive_energy_district neighbourhoods sustainable urban development program started part strategic energy_technology plan action smart_city communities addition positive_energy_district supported horizon lighthouse projects urban europe joint programming initiative annex international energy agency energy building communities
#
# Passage 5: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy_balance district level evaluate energy performance district striving achieve positive_energy_district status work evaluation net carbon_dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable_energy city level many methods exist developing greenhouse_gas inventories furthermore several community scale protocols evolved intergovernmental panel climate_change ipcc guidelines national greenhouse_gas inventories international standard greenhouse_gas city global protocol community scale greenhouse_gas emissions already mentioned baseline_emission_inventory electric driven thermal_energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon_dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district_heating network dhn solar_thermal system seasonal thermal_energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive_energy_district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy_production swiss village reduction carbon_dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon_footprint district milan including building aiming becoming first italian social_housing project characterized net zero emissions results obtained showed greenhouse_gas emissions pertain operational stage
#
# Answer: since scope scientific research broadening building towards wider scale new methods metrics required framework available strives encompass key pillars sustainability evaluation multiple key performance indicators available tools mainly focus strategy renovating existing building stock mapping existing initiative especially european level methodology proposed gabaldon moreno calculate energy _ balance district level evaluate energy performance district striving achieve positive _ energy _ district status work evaluation net carbon _ dioxide equivalent co 2eq emissions difference total co 2eq emissions due imported primary energy total co 2eq avoided thanks export renewable _ energy city level many methods exist developing greenhouse _ gas inventories furthermore several community scale protocols evolved intergovernmental panel climate _ change ipcc guidelines national greenhouse _ gas inventories international standard greenhouse _ gas city global protocol community scale greenhouse _ gas emissions already mentioned baseline _ emission _ inventory electric driven thermal _ energy production plant us delivered users nevertheless globally shared approach still lacking especially since methods adopted building oriented analysis frequently transposed district level table lists main factors distinguish approaches adopted scientific literature addressing environmental analysis district communities latter usually intended determine carbon _ dioxide co 2eq emissions avoided following installation renewable based plants papers focus building sector although transport sector considered ascione applied integrated approach retrofit building neighbourhood naples calculating co 2eq due electricity demand natural gas combustion kim investigated environmental performance netzero energy community equipped heat pumps district _ heating network dhn solar _ thermal system seasonal thermal _ energy storages proposed configuration allowed avoid co 2eq emissions compared baseline case volpe analysed small neighbourhood twenty building south italy designed operated positive _ energy _ district latter equipped photovoltaic pv panels biomass based dhn electricity supplied pv panels considered emission free whereas emission factor equal kgco 2eq kwh assigned biomass combustion sameti highighat optimized new district different scenarios using mixed integer linear programming technique co 2eq emissions balance accounted combustion based emissions well indirect emissions related purchase electricity power grid pg orehounig considered emissions released renewable based electric energy _ production swiss village reduction carbon _ dioxide emissions achieved means dhn activated biomass pv panels small hydropower famiglietti adopted net balance approach evaluating carbon _ footprint district milan including building aiming becoming first italian social _ housing project characterized net zero emissions results obtained showed greenhouse _ gas emissions pertain operational stage
#
# --------------------------------------------------

# %%
# !pip install transformers sentence-transformers scikit-learn numpy datasets
# !pip install evaluate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (1.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Using cached datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 1.4 MB/s eta 0:00:00
# Using cached datasets-3.1.0-py3-none-any.whl (480 kB)
# Installing collected packages: datasets, evaluate
#   Attempting uninstall: datasets
#     Found existing installation: datasets 1.18.0
#     Uninstalling datasets-1.18.0:
#       Successfully uninstalled datasets-1.18.0
# Successfully installed datasets-3.1.0 evaluate-0.4.3

# %%
#USING THE GPT OPEN AI

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Collecting openai
#   Downloading openai-1.55.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.55.3-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.4
#     Uninstalling openai-1.54.4:
#       Successfully uninstalled openai-1.54.4
# Successfully installed openai-1.55.3

# %%
import openai
#### Access to API and Drive
# Set up for the  OpenAI API key
openai.api_key = input("OpenAI-key")

# Mounting Google Drive:
from google.colab import drive
drive.mount('/content/drive')

# %%
import openai
print(openai.__version__)

# !pip install openai==0.28
# !pip install transformers datasets faiss-cpu sentence-transformers
# Out:
# 0.28.0
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.28) (4.12.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.9.0.post1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)

# %%
#pip install --upgrade openai

# %%
#RAG WITH THE CHUNKED CORPUS

# %%
# Import required libraries
import openai
import torch
import json
from transformers import BertForQuestionAnswering, BertTokenizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


# Setting up the OpenAI API key
openai.api_key = ("OpenAIkey")


# Loading the Sentence Transformer model
sentence_model = SentenceTransformer('all-MiniLM-L6-v2')

# Loading the fine-tuned BERT model and tokenizer for extractive QA
model_path = "/content/drive/MyDrive/fine_tuned_PED_modelx"  # Path to the fine-tuned model
bert_model = BertForQuestionAnswering.from_pretrained(model_path)
bert_tokenizer = BertTokenizer.from_pretrained(model_path)

# Loading the corpus
with open('/content/drive/MyDrive/chunked_corpus.json', 'r') as f:
    corpus = json.load(f)

# Extracting texts and metadata for embedding
if isinstance(corpus, list):
    # For a list of documents
    texts = []
section_metadata = []

for document in corpus:
    if 'sections' in document:
        for section in document['sections']:
            for chunk in section.get('chunks', []):
                texts.append(chunk)  # Add chunk text
                section_metadata.append((document.get('title', 'Chunks'), section.get('name', 'Chunks')))  # Add metadata

    #texts = [
     #   chunk  # Using chunks directly for embedding
     #  for document in corpus if 'sections' in document
      #  for section in document['sections']
      #  for chunk in section.get('chunks', [])
   # ]

# Computing the embeddings for chunked texts
if texts:
    corpus_embeddings = sentence_model.encode(texts, show_progress_bar=True)
else:
    print("No texts found for embedding.")

# The function for retrieving the relevant passages based on chunks
def retrieve_relevant_passages(query, top_k=5, min_similarity=0.40):
    query_embedding = sentence_model.encode([query])
    similarities = cosine_similarity(query_embedding, corpus_embeddings)[0]

    # Top k relevant passages based on similarity
    top_indices = np.argsort(similarities)[-top_k:][::-1]

    # Get passages that have similarity above the threshold
    relevant_texts = [(texts[i], section_metadata[i], similarities[i]) for i in top_indices if similarities[i] > min_similarity]

    if not relevant_texts:
        return [], False
    return relevant_texts, True

# The function for the extractive QA using BERT
def answer_question_with_bert(question, context):
    inputs = bert_tokenizer.encode_plus(question, context, return_tensors='pt', max_length=512,
                                        truncation=True, padding='max_length')
    input_ids = inputs['input_ids'].to(bert_model.device)
    attention_mask = inputs['attention_mask'].to(bert_model.device)

    with torch.no_grad():
        outputs = bert_model(input_ids, attention_mask=attention_mask)

    answer_start = torch.argmax(outputs.start_logits)
    answer_end = torch.argmax(outputs.end_logits)

    answer = bert_tokenizer.convert_tokens_to_string(
        bert_tokenizer.convert_ids_to_tokens(input_ids[0][answer_start:answer_end + 1])
    ).replace('[SEP]', '').replace('[CLS]', '').strip()

    return answer

# Function for the generative QA using GPT
def generate_answer_with_gpt(query, relevant_passages):
    # Concatenating the relevant passages to use as context
    context = " ".join([text for text, _, _ in relevant_passages])

    # Formatting the input text for the model
    input_text = f"Question: {query}\nContext: {context}\nAnswer:"

    # Calling the OpenAI API
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": input_text},  # User's input
        ],
        max_tokens=700,  # response length
        temperature=0.7,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Extract and returning the generated answer
    generated_answer = response['choices'][0]['message']['content'].strip()
    return generated_answer

# List of questions to process
questions = [
    "How do Positive Energy Districts contribute to urban sustainability?",
    "What are the main challenges in implementing Positive Energy Districts?",
    "which district in riga have used the wind power energy",
    "Whats the population size in borlänge?",
    "What is the annual renewal generation district in Umea?",
    "How do tools and methodologies contribute to the design of positive energy districts?",
    "In what ways do PEDs integrate data-driven design principles?",
    "Why are tools for engaging multiple stakeholders essential in PED planning?",
    "What distinguishes net-zero energy buildings from positive energy districts?",
    "How do varying scales and boundary definitions influence PED analysis?",
    "What are positive energy districts?",
    "How does building envelope retrofitting in PEDs work?",
    "What are specific examples of how PEDs are implemented in Italy?",
    "What are the primary renewable energy technologies proposed for the transition to a Positive Energy District in Riga?",
    "What is the purpose of multi-stakeholder engagement tools?",
    "What are the differences between net zero energy building and positive energy district?",
    "How do different scales and evaluation boundaries affect positive energy district analysis?",
    "What is involved in the planning of positive energy districts?",
    "What is the habitat of Polar Bears?"
]

# Looping through the questions and processing
for question in questions:
    relevant_passages, is_relevant = retrieve_relevant_passages(question, top_k=5)

    if is_relevant:
        # Using BERT for extractive QA
        contexts = [text for text, _, _ in relevant_passages]
        bert_answer = answer_question_with_bert(question, " ".join(contexts[:5]))

        # Using GPT for generative QA
        generated_answer = generate_answer_with_gpt(question, relevant_passages)

        # Printing the output answers and relevant passages
        print(f"Question: {question}")
        print(f"Extractive Answer (BERT): {bert_answer}")
        print(f"Generated Answer (GPT): {generated_answer}")

        print("\nRelevant Passages:")
        for i, (passage, meta, similarity) in enumerate(relevant_passages, 1):
            print(f"Passage {i} (Parent Section: {meta[0]}, Section: {meta[1]}, Similarity: {similarity:.2f}): {passage}\n")

        print("-" * 50)
    else:
        print(f"Question: {question}")
        print("No relevant answer.")
        print("-" * 50)
# Out:
# Batches:   0%|          | 0/103 [00:00<?, ?it/s]
# Question: How do Positive Energy Districts contribute to urban sustainability?
# Extractive Answer (BERT): how do positive energy districts contribute to urban sustainability ?  positive _ energy _ district could impact social economic energy environmental societal goals positive _ energy _ district integrates main paradigms smart sustainable city incrementally introduced integrated energy planning many city communities coming years suggested renovation wave environmental goals set community district level ambitious challenging characterizing positive _ energy _ district processes positive _ energy _ district designs dynamic multi scale multi disciplinary urban environment conclusions emergence positive _ energy _ district represents significant shift toward sustainable urbanism energy _ transition underscoring need comprehensive approach address multifaceted urban challenges publication delves intricate web factors influencing positive _ energy _ district development
# Generated Answer (GPT): Positive Energy Districts contribute to urban sustainability by integrating various key paradigms of smart and sustainable city planning. They focus on incrementally introducing integrated energy planning in many city communities over the coming years, which can help achieve environmental goals set at the community and district level. These districts aim to be ambitious and challenging in character, emphasizing the importance of dynamic, multi-scale, and multi-disciplinary urban environment designs.
#
# The emergence of Positive Energy Districts represents a significant shift toward sustainable urbanism and energy transition. They highlight the need for a comprehensive approach to address multifaceted urban challenges, emphasizing the necessity of integrated tools and methods to unravel the complexities associated with their design. Positive Energy Districts go beyond just energy balance considerations, exploring the interplay of governance, technology, stakeholders, and urban dynamics in the pursuit of sustainability.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.83): positive_energy_district could impact social economic energy environmental societal goals
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): positive_energy_district integrates main paradigms smart sustainable city incrementally introduced integrated energy planning many city communities coming years suggested renovation wave
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): environmental goals set community district level ambitious challenging characterizing positive_energy_district
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): processes positive_energy_district designs dynamic multi scale multi disciplinary urban environment
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): conclusions emergence positive_energy_district represents significant shift toward sustainable urbanism energy_transition underscoring need comprehensive approach address multifaceted urban challenges publication delves intricate web factors influencing positive_energy_district development emphasizing necessity integrated tools methods unravels complexities associated positive_energy_district designs transcending mere energy_balance exploring interplay governance technology stakeholder urban dynamics shift
#
# --------------------------------------------------
# Question: What are the main challenges in implementing Positive Energy Districts?
# Extractive Answer (BERT): positive _ energy _ district project positive _ energy _ district integration furthermore developing implementing positive _ energy _ district requires significant time resources managing multiple independent energy district involve substantial overheads heavy reliance digital technology may pose barriers individuals communities less familiar advanced technology necessitating inclusive strategy managing production peaks within positive _ energy _ district defining role building district future energy _ system pose additional challenges effective management positive _ energy _ district could impact social economic energy environmental societal goals environmental goals set community district level ambitious challenging characterizing positive _ energy _ district tenets together positive _ energy _ district guiding principles pillars presented prior section paper methodology followed results discussion section
# Generated Answer (GPT): Some of the main challenges in implementing Positive Energy Districts include:
#
# 1. Significant time and resources: Developing and implementing Positive Energy Districts requires a significant investment of time and resources. This can pose challenges in terms of funding and project management.
#
# 2. Managing multiple independent energy sources: Positive Energy Districts often involve managing multiple independent energy sources, which can lead to substantial overheads and complexities in coordination.
#
# 3. Reliance on digital technology: Positive Energy Districts rely heavily on digital technology for monitoring, control, and optimization. This may pose barriers for individuals and communities that are less familiar with advanced technology, necessitating an inclusive strategy for implementation.
#
# 4. Managing production peaks: Balancing energy production peaks within a Positive Energy District can be challenging, especially when integrating renewable energy sources. Effective strategies need to be in place to manage fluctuations in energy supply and demand.
#
# 5. Defining the role of buildings in the district's future energy system: Determining the role that buildings will play in the future energy system of the district can pose additional challenges. This includes considerations such as energy storage, distribution, and demand-side management.
#
# 6. Impact on social, economic, and environmental goals: Implementing Positive Energy Districts can have wide-ranging impacts on social, economic, and environmental goals set by the community at the district level. Balancing these goals while achieving ambitious energy targets can be a complex task.
#
# Overall, effective management of Positive Energy Districts requires careful planning, coordination, and consideration of various technical, social, and economic factors.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.78): positive_energy_district project
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): positive_energy_district integration furthermore developing implementing positive_energy_district requires significant time resources managing multiple independent energy district involve substantial overheads heavy reliance digital technology may pose barriers individuals communities less familiar advanced technology necessitating inclusive strategy managing production peaks within positive_energy_district defining role building district future energy_system pose additional challenges effective management
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): positive_energy_district could impact social economic energy environmental societal goals
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): environmental goals set community district level ambitious challenging characterizing positive_energy_district
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.74): tenets together positive_energy_district guiding principles pillars presented prior section paper methodology followed results discussion section interview data presented discussed context existing research followed conclusions
#
# --------------------------------------------------
# Question: which district in riga have used the wind power energy
# Extractive Answer (BERT):
# Generated Answer (GPT): The district in Riga that has used wind power energy is not explicitly mentioned in the provided context. However, it is mentioned that wind energy is often underrated in urban contexts, and researchers argue for a holistic economic analysis to find cost-optimal solutions for achieving positive energy districts. If you need more specific information about a particular district in Riga that has utilized wind power energy, further research or inquiry may be necessary.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.46): modelled system includes building owned riga technical university rtu see figure table located peninsula ķīpsala riga latvia include research building dormitories swimming pool detailed information enclosing structures engineering system gathered building built recently renovated within last decade research building still building phase however potential energy_demand estimated building parameters several building data centres server rooms located considered potential heat source hp installations indirectly
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.46): measures implemented new urban district low temperature district_heating networks common swedish positive_energy_district seen vallastaden brunnshög framework conditions concerning national planning regulation affect development positive_energy_district follow energy performance new building two years building use regulated national building regulation sweden however swedish case_study show municipalities using energy performance certificates follow energy requirements currently consequences exceeding
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.45): europe booklet among things found actual feasibility many projects yet consolidated positive_energy_district strategy still need tested optimised often term positive energy used narrow sense simple energy_balance used assessment methodology evaluate district positive_energy_district existing literature suggests things stand investigated district achieving positive_energy_district status additionally certain technology useable urban context wind energy often underrated reasons many researchers argue holistic
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.45): economic analysis highsuffiency district find cost optimal solution laitinen positive_energy_district challenging meaningful progress developing renewable_energy technology methods contribute energy_transition clime target plan review renewable_energy technology status sustainable development østergaard showed recent progress repowering wind farms latest technology profitable moreover still unexploited wind wave solar power resources among others photovoltaic pv system improving performance feasibility
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.45): performances facilitate implementation positive_energy_district around europe
#
# --------------------------------------------------
# Question: Whats the population size in borlänge?
# No relevant answer.
# --------------------------------------------------
# Question: What is the annual renewal generation district in Umea?
# Extractive Answer (BERT): yearly balance district level per fichera optimal dimension production energy _ storage district needs investigated since much installed production storage potential might lead building mostly self sufficient limits sharing potential could restrict flexibility opportunities district might affect success positive _ energy _ district integrated innovative technology mentioned key perspective positive _ energy _ district necessary achieving annual energy surplus mentioned key challenge ensure energy _ system reliable need eur million incube mainly focus b6 demonstration proposed innovations building b1 b5 enhance district level approach favoring emergence renewable _ energy community santa chiara district trento figure one three demo sites horizon europe project called incube project aims develop tools methodology accelerate rate deep renewal essential renovation wave sweep european _ union coming years achieve goal decarbonization project
# Generated Answer (GPT): The annual renewal generation district in Umea is not specifically mentioned in the provided context. It seems like the information provided is related to a different district or project, not in Umea. If you have any other questions or need further clarification, feel free to ask.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.51): yearly balance district level per fichera optimal dimension production energy_storage district needs investigated since much installed production storage potential might lead building mostly self sufficient limits sharing potential could restrict flexibility opportunities district might affect success positive_energy_district integrated innovative technology mentioned key perspective positive_energy_district necessary achieving annual energy surplus mentioned key challenge ensure energy_system reliable need
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.49): eur million incube mainly focus b6 demonstration proposed innovations building b1 b5 enhance district level approach favoring emergence renewable_energy community santa chiara district trento figure one three demo sites horizon europe project called incube project aims develop tools methodology accelerate rate deep renewal essential renovation wave sweep european_union coming years achieve goal decarbonization project involves partners different european countries santa chiara district status progressive
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.46): results district identified methodology validated applying case_study alcorcón selected district alcorcón presents beginning potential characteristics transformed positive_energy_district recent years municipality promoted many renewable_energy initiative concentrated area approximately km defined case_study district figure
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.45): constructions heritage status means insulation retrofitting challenging terms investment e1 significant changes however district pobles de l oest jesús benimaclet score lower probably due lower average per capita income means higher public support needed current developments mobility u7 criterion shown fig reveals significant variation among district comparison fig interesting regard fig illustrates scores district map criteria renewable_energy resources t1 current developments mobility u7 given increased
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.45): district including demand aerothermal system addition could surplus gwh per year serve cover energy_demand areas city alcorcón
#
# --------------------------------------------------
# Question: How do tools and methodologies contribute to the design of positive energy districts?
# Extractive Answer (BERT):
# Generated Answer (GPT): The tools and methodologies play a crucial role in the design of positive energy districts by providing a framework for achieving sustainable and regenerative goals. While the term "positive energy district" may initially focus on energy balance between supply and demand, it is essential to consider a broader perspective that includes sustainable design, environmental quality, and climate change considerations. The discussion around tools and methods in positive energy district design must be viewed within a larger performative framework to address the complex challenges involved.
#
# One of the gaps between existing tools and positive energy district design in practice is the lack of unified design frameworks. This gap is primarily due to the novelty of the field and the diversity of local contexts, which require tailored approaches and distinct tools for different scenarios. Addressing this gap necessitates developing tools that can adapt to varying regulation types, renewable energy sources, energy storage options, consumption patterns, and local economic opportunities. Case studies of positive energy districts in the EU and other regions can provide valuable insights into the tools needed to bridge this gap and effectively design positive energy districts.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): tenets together positive_energy_district guiding principles pillars presented prior section paper methodology followed results discussion section interview data presented discussed context existing research followed conclusions
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): positive_energy_district integrates main paradigms smart sustainable city incrementally introduced integrated energy planning many city communities coming years suggested renovation wave
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.76): positive_energy_district project
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.75): Question: what is the role of tools and methods in positive_energy_district design Answer: term “positive energy district” positive_energy_district initially appears focus solely energy balance supply demand however when viewed context broader discussions encompassing sustainable design goals sdgs regenerative design environmental quality climate_change complex picture emerges discussion becomes essential examine role tools methods positive_energy_district design within larger performative framework
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.75): Question: what are the gaps between the existing tools and positive_energy_district design in practice Answer: significant gap unified positive_energy_district design frameworks largely attributed field’s novelty diversity local contexts factors including varying regulation types renewables energy_storage consumption patterns local economic opportunities require tailored approach necessitating distinct tools different scenarios examining case studies positive_energy_district eu net provided insights tools
#
# --------------------------------------------------
# Question: In what ways do PEDs integrate data-driven design principles?
# Extractive Answer (BERT): question : how do positive _ energy _ district embrace data driven design answer : role tools positive _ energy _ district design viewed broader context architectural shift toward data driven processes transformative shift propelled range innovative methods technology including smart controls ai digital twinning building information modeling bim technology serve bridges physical digital dimensions design potentially revolutionizing entire design process offering multifaceted benefits spanning prediction evaluation external data sources simplifying complex analyses design tasks combining tools table unified workflow allows cross referencing data insights advanced design context parametric platforms facilitate seamless data transfer different tools computational methods via plugins table modules handling numerical geometric data connect diverse assessment objectives integrated workflows streamline capture relay simulation input parameters across various platforms refining results without direct linkage instance digital context architectural shift toward data driven processes transformative shift propelled range innovative methods technology including smart controls ai digital twinning building information modeling bim technology serve bridges physical digital dimensions design potentially revolutionizing entire design process offering multifaceted benefits spanning prediction evaluation collaboration optimization operational phases technology bridge physical digital realms potentially revolutionizing design process integrates public health data assessing design impacts health support urban designs additionally decodingspaces toolbox promotes healthier positive _ energy _ district facilitating walkability enhancing contact nature empowering positive _ energy _ district planners craft health enhancing spaces core workflow lies tool ’ s inherent capacity seamless data transfer instance grasshopper robust data management interoperability via plugins like tt toolbox data streaming ensures consistent data flow table fosters together insights inputs stakeholder facilitate integration diverse expertise promote widely participatory design process
# Generated Answer (GPT): Positive Energy Districts (PEDs) integrate data-driven design principles in several ways:
#
# 1. **Smart Controls and AI**: PEDs leverage smart controls and artificial intelligence to optimize energy consumption and operational efficiency based on real-time data analysis.
#
# 2. **Digital Twinning**: By creating digital twins of buildings and infrastructure within the district, PEDs can simulate and test various design scenarios to identify the most energy-efficient solutions.
#
# 3. **Building Information Modeling (BIM)**: BIM technology is used in PEDs to bridge the physical and digital dimensions of design, enabling a more integrated and data-driven approach to building design and management.
#
# 4. **Parametric Platforms**: These platforms facilitate seamless data transfer and computational methods across different tools, allowing for advanced design analysis and optimization based on diverse data sources.
#
# 5. **Integration of External Data Sources**: PEDs incorporate external data sources, such as public health data, to assess design impacts on health and support the creation of healthier urban environments.
#
# 6. **Collaborative Design Processes**: Tools like the decodingspaces toolbox promote collaboration and stakeholder engagement throughout the design process, ensuring a holistic and inclusive approach to creating sustainable and resilient urban districts.
#
# Overall, the integration of data-driven design principles in PEDs revolutionizes the design process by offering predictive capabilities, enabling complex analyses, and fostering collaboration among stakeholders to create innovative and sustainable urban spaces.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.57): Question: how do positive_energy_district embrace data driven design Answer: role tools positive_energy_district design viewed broader context architectural shift toward data driven processes transformative shift propelled range innovative methods technology including smart controls ai digital twinning building information modeling bim technology serve bridges physical digital dimensions design potentially revolutionizing entire design process offering multifaceted benefits spanning prediction evaluation
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.52): external data sources simplifying complex analyses design tasks combining tools table unified workflow allows cross referencing data insights advanced design context parametric platforms facilitate seamless data transfer different tools computational methods via plugins table modules handling numerical geometric data connect diverse assessment objectives integrated workflows streamline capture relay simulation input parameters across various platforms refining results without direct linkage instance digital
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.51): context architectural shift toward data driven processes transformative shift propelled range innovative methods technology including smart controls ai digital twinning building information modeling bim technology serve bridges physical digital dimensions design potentially revolutionizing entire design process offering multifaceted benefits spanning prediction evaluation collaboration optimization operational phases technology bridge physical digital realms potentially revolutionizing design process
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.49): integrates public health data assessing design impacts health support urban designs additionally decodingspaces toolbox promotes healthier positive_energy_district facilitating walkability enhancing contact nature empowering positive_energy_district planners craft health enhancing spaces core workflow lies tool’s inherent capacity seamless data transfer instance grasshopper robust data management interoperability via plugins like tt toolbox data streaming ensures consistent data flow table fosters
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.48): together insights inputs stakeholder facilitate integration diverse expertise promote widely participatory design process address significant gap positive_energy_district design practices tools offer continuous conceptual framework guides stakeholder throughout various stages design process framework ensures design decisions made isolation part holistic inclusive approach creating sustainable resilient urban district embracing data driven design role tools positive_energy_district design viewed broader
#
# --------------------------------------------------
# Question: Why are tools for engaging multiple stakeholders essential in PED planning?
# Extractive Answer (BERT): question : what is the purpose of multi stakeholder engagement tools
# Generated Answer (GPT): Tools for engaging multiple stakeholders are essential in Positive Energy District (PED) planning for several reasons:
#
# 1. Collaboration among diverse stakeholders: Designing at the district scale requires collaboration among a wide range of stakeholders, including design experts, homeowners, local communities, policymakers, urban ecologists, and energy service providers. Effective collaboration among these stakeholders is essential to devise a strategy that harmonizes multifaceted objectives for an ambitious project encompassing social, economic, and environmental considerations.
#
# 2. Stakeholder management: Tools for engaging multiple stakeholders help in managing the diverse interests and priorities of different groups involved in the PED planning process. By engaging target users and facilitating dialogue among stakeholders, these tools ensure that a variety of perspectives are taken into consideration in the planning and decision-making processes.
#
# 3. Supporting cooperation: Tools for multi-stakeholder engagement support the central purpose of stakeholder management by enabling structured frameworks for collaboration and exchange of solutions. These tools help in defining and adapting various aspects of the PED design methodology based on the input and feedback from different stakeholders.
#
# 4. Addressing intervention points: In the PED development process, there are critical decision-making junctures known as intervention points where stakeholders need to navigate challenges and make key choices. Using various tools for stakeholder engagement at these intervention points ensures open dialogue, consultative processes, and adequate consideration of stakeholders' interests and priorities.
#
# 5. Smooth communication and cooperation: By employing tools for engaging multiple stakeholders, PED planners can establish clear membership and cooperation protocols, facilitate effective communication among partners, and engage a wider set of stakeholders in the planning process. This helps in creating a transparent and inclusive decision-making framework that considers the interests and priorities of all stakeholders involved.
#
# In summary, tools for engaging multiple stakeholders in PED planning are crucial for ensuring effective collaboration, managing diverse interests, supporting cooperation, addressing intervention points, and promoting smooth communication and cooperation among stakeholders throughout the planning process.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.63): Question: what is the purpose of multi stakeholder engagement tools Answer: designing district scale necessitates collaboration among diverse set stakeholders including design experts homeowners local communities policymakers urban ecologists energy_service providers effective collaboration among stakeholders indispensable devising strategy harmonizes multifaceted objectives ambitious project encompassing social economic environmental considerations context positive_energy_district design tools support
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.62): central purpose stakeholder management engage targetusers facilitate dialogue stakeholder ensure diverse interests priorities taken consideration outlined fig characterization target users enables define adapt several aspects methodology positive_energy_district design review literature selection demonstrates activities aimed supporting cooperation among stakeholder usually included positive_energy_district design methodologies consequently absence structured framework stakeholder tend collaborate exchange
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.59): solution booklet delineate relevant planning scales spanning regional building levels however harmonizing design phases stakeholder interests scales challenging due frequent intersections practice elements interconnected critical decision making junctures known intervention points stakeholder navigate challenges intervention points using various tools given fluid roles stakeholder positive_energy_district development becomes crucial scrutinize pertinent stakeholder tools employed intervention point
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.58): ensure open dialogue consultative process adequate consideration stakeholders’ interests priorities transparent membership cooperation protocol smooth effective communication partners wider set stakeholders closely related relational components q collaborative governance insights thus provide open framework where core stakeholders join forces accordance specific interests thereby create common programme positive_energy_district city
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.58): advocate spatial tiered stakeholder categorization emphasizing importance multi level decision making louisiana planning assembly kit positive_energy_district solution booklet delineate relevant planning scales spanning regional building levels however harmonizing design phases stakeholder interests scales challenging due frequent intersections practice elements interconnected critical decision making junctures known ‘intervention points ’ stakeholders navigate challenges intervention points using various
#
# --------------------------------------------------
# Question: What distinguishes net-zero energy buildings from positive energy districts?
# Extractive Answer (BERT): introduction basic principle positive _ energy _ district create area within city boundaries capable generating energy consumed agile flexible enough respond variation energy _ market positive _ energy _ district aim achieve annual surplus net energy another notion named net zero district urban area neighborhood total energy _ consumption equal energy produced specified period typically annually primary goal net zero district balance energy _ use production resulting net zero energy footprint unlike decarbonization process positive _ energy _ district concept developed previous ideas nearly net positive zero energy building extending single building district scale order exploit energy mutuality building urban decarbonization need broaden perspective arises several key aspects improvements single building approach example district approaches could offer benefits terms energy _ system design integration terms striving towards optimized urban morphology district scale energy _ system could offer economical strategy varying loads support demo building reach positive energy building status nordic climate however results revealed proved difficult reach net zero even including energy demands hand similar study performed italy magrini showed demo building producing energy surplus meeting positive energy building requirement however demo building located outskirts city highlights yet positive _ energy _ district boundaries expand made flexible provided virtual positive _ energy _ district essential point highlight several definitions within field positive _ energy _ district high performance neighborhoods refer similar entities among commonly mentioned net zero emission neighborhood net zero energy district positive energy community sustainable plus energy neighborhood nearly zero energy neighborhood net zero energy community low energy district nearly zero energy district net zero energy district positive energy block definitions share several aspects including definition specific geographical boundary particular positive _ energy _ district differently energy sufficiency frequently mistaken energy _ efficiency energy sufficiency includes minimum energy necessary provide comfortable living environment energy _ efficiency related design consequently building district neighbourhoods potential use energy optimally reduce wasted energy thus building potential energy _ efficient lies design exploited realised operational phase energy _ efficiency combination energy sufficiency results low energy _ consumption interactions building
# Generated Answer (GPT): Net-zero energy buildings and positive energy districts are related concepts within the realm of sustainable urban development, but they have distinct differences:
#
# 1. Scope: Net-zero energy buildings refer to individual structures, such as a single building or a small group of buildings, that aim to produce as much energy as they consume over a specified period, typically annually. On the other hand, positive energy districts encompass larger areas within city boundaries that are capable of generating more energy than they consume, creating an annual surplus of energy.
#
# 2. Scale: Net-zero energy buildings are focused on achieving balanced energy consumption and production at a building level, whereas positive energy districts extend this concept to a district or neighborhood scale. Positive energy districts aim to optimize energy production and consumption across multiple buildings and infrastructure within a defined area.
#
# 3. Integration: Positive energy districts involve a more comprehensive approach to energy system design and integration compared to individual net-zero energy buildings. By considering the energy needs and opportunities at a district level, positive energy districts can implement more efficient and effective energy solutions that benefit the entire community.
#
# 4. Flexibility and agility: Positive energy districts are designed to be agile and flexible in responding to variations in energy market conditions and evolving energy needs within the community. This adaptability allows positive energy districts to effectively manage energy production and consumption in a dynamic urban environment.
#
# In summary, while net-zero energy buildings focus on achieving energy balance at the building level, positive energy districts extend this concept to a larger scale, aiming to create urban areas that generate more energy than they consume and are capable of adapting to changing energy demands and market conditions.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.71): introduction basic principle positive_energy_district create area within city boundaries capable generating energy consumed agile flexible enough respond variation energy_market positive_energy_district aim achieve annual surplus net energy another notion named net zero district urban area neighborhood total energy_consumption equal energy produced specified period typically annually primary goal net zero district balance energy_use production resulting net zero energy footprint unlike
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.69): decarbonization process positive_energy_district concept developed previous ideas nearly net positive zero energy building extending single building district scale order exploit energy mutuality building urban decarbonization need broaden perspective arises several key aspects improvements single building approach example district approaches could offer benefits terms energy_system design integration terms striving towards optimized urban morphology district scale energy_system could offer economical
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.66): strategy varying loads support demo building reach positive energy building status nordic climate however results revealed proved difficult reach net zero even including energy demands hand similar study performed italy magrini showed demo building producing energy surplus meeting positive energy building requirement however demo building located outskirts city highlights yet positive_energy_district boundaries expand made flexible provided virtual positive_energy_district essential point highlight
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.66): several definitions within field positive_energy_district high performance neighborhoods refer similar entities among commonly mentioned net zero emission neighborhood net zero energy district positive energy community sustainable plus energy neighborhood nearly zero energy neighborhood net zero energy community low energy district nearly zero energy district net zero energy district positive energy block definitions share several aspects including definition specific geographical boundary particular
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.65): positive_energy_district differently energy sufficiency frequently mistaken energy_efficiency energy sufficiency includes minimum energy necessary provide comfortable living environment energy_efficiency related design consequently building district neighbourhoods potential use energy optimally reduce wasted energy thus building potential energy_efficient lies design exploited realised operational phase energy_efficiency combination energy sufficiency results low energy_consumption interactions building
#
# --------------------------------------------------
# Question: How do varying scales and boundary definitions influence PED analysis?
# Extractive Answer (BERT): additional complexities related boundary definition increased number interdependent design factors must taken account thus new analysis tools methods domains infrastructural environmental come play discuss four categories methods tools design positive _ energy _ district related many operational scales spatial scale system scale microclimate scale hybrid scale spatial scale hundreds thousands building district requires different energy analysis methods tools single building scale two reasons first uncertainties potentials instead positive _ energy _ district assessment ensure district optimally utilises individual potential generate renewable _ energy usage pefs energy _ balance seen problematic calculation pefs standardised always solely based physical considerations different countries moreover positive _ energy _ district assessment usually carried future district therefore would require future pefs might better use standardised objective criterium assess energy flows example carbon _ dioxide equivalents rather relying geographic functional virtual assessment boundaries
# Generated Answer (GPT): Varying scales and boundary definitions can significantly influence the analysis of Positive Energy Districts (PEDs) in several ways. Firstly, the spatial scale at which the analysis is conducted, whether it is at the building level, district level, or beyond, can impact the accuracy and complexity of the assessment. Different scales require different energy analysis methods and tools, as the number of interdependent design factors and uncertainties increase with the scale.
#
# Boundary definitions also play a crucial role in PED analysis. The definition of boundaries, such as geographical, functional, or virtual boundaries, can affect how energy flows are assessed within a district. For example, a geographical boundary may encompass the physical limits of a district, while a functional boundary might consider interconnected buildings as part of a single system. A virtual boundary can complicate the analysis by including energy demand that is met outside the physical boundaries of the district.
#
# Moreover, the definition of boundaries can impact the calculation of key metrics in PED analysis, such as the Positive Energy Balance (PEB). The annual PEB of a district is determined by considering the energy exported and imported within the defined boundaries. This calculation may be influenced by factors such as the primary energy conversion factors specific to the country where the district is located.
#
# In addition, the consideration of embodied energy and life cycle assessment boundaries can impact the overall assessment of a PED. The embodied energy of materials used in construction and maintenance should align with the physical boundaries of the district to provide a comprehensive analysis of energy flows.
#
# Overall, varying scales and boundary definitions in PED analysis require careful consideration to ensure accurate assessments and decision-making. Standardized methodologies and tools can help streamline the analysis process and facilitate comparisons between different projects and regions.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.48): additional complexities related boundary definition increased number interdependent design factors must taken account thus new analysis tools methods domains infrastructural environmental come play discuss four categories methods tools design positive_energy_district related many operational scales spatial scale system scale microclimate scale hybrid scale spatial scale hundreds thousands building district requires different energy analysis methods tools single building scale two reasons first uncertainties
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.47): potentials instead positive_energy_district assessment ensure district optimally utilises individual potential generate renewable_energy usage pefs energy_balance seen problematic calculation pefs standardised always solely based physical considerations different countries moreover positive_energy_district assessment usually carried future district therefore would require future pefs might better use standardised objective criterium assess energy flows example carbon_dioxide equivalents rather relying
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.47): geographic functional virtual assessment boundaries geographical boundary means building delimited spatial physical boundaries functional boundary building close interconnected virtual boundary present energy_demand met generation unit located outside geographic boundaries become positive_energy_district annual negative peb achieved primary energy exported imported within district boundaries annual peb determined converting delivered exported energy primary energy using country specific primary energy
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.46): additionally includes private motorised everyday mobility lastly peq omega considers embodied energy entire life cycle assessment boundary aligns physical district boundary regard positive_energy_district shells defined zqw paper focuses peq beta become positive_energy_district peb must greater calculated peb target value scales floor area ratio far ratio gross floor area tgfa site coverage area building adjustable peb target value right side equation described density factor density factor derived using
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.46): positive_energy_district framework pefs strong impact positive_energy_district decision within mc methodology neither strict specification pefs eu level strict adherence standard calculation therefore values calculations differ eu member state total pef general electricity mix instance germany austria furthermore case_study district modelled year using current pefs future pefs clouded high uncertainty underlying conditions change quickly years comparing results different case_study district variant con
#
# --------------------------------------------------
# Question: What are positive energy districts?
# Extractive Answer (BERT): positive _ energy _ district positive _ energy _ district positive _ energy _ district project positive _ energy _ district could impact social economic energy environmental societal goals positive _ energy _ district models area
# Generated Answer (GPT): Positive energy districts are urban areas designed and developed with a focus on sustainable energy practices and technologies. These districts aim to produce more energy than they consume, leading to a net positive energy balance. By incorporating renewable energy sources, energy-efficient infrastructure, and innovative technologies, positive energy districts contribute to environmental sustainability, energy independence, and overall community resilience. They also have the potential to positively impact social, economic, and environmental goals by promoting cleaner energy use, reducing greenhouse gas emissions, and fostering a more sustainable way of living.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.88): positive_energy_district
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.88): positive_energy_district
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.85): positive_energy_district project
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.81): positive_energy_district could impact social economic energy environmental societal goals
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.78): positive_energy_district models area
#
# --------------------------------------------------
# Question: How does building envelope retrofitting in PEDs work?
# Extractive Answer (BERT):
# Generated Answer (GPT): Building envelope retrofitting in Positive Energy Districts (PEDs) works by implementing both active and passive measures to improve energy efficiency and reduce carbon emissions in buildings. Active retrofitting measures may include installing heat pumps and photovoltaic systems, while passive measures involve improving the building envelope through insulation and energy-efficient windows.
#
# In a study using a Mixed Integer Linear Programming (MILP) model, researchers found that retrofitting the building envelope with insulation and multi-glazed windows can have a significant impact on the technical feasibility and environmental footprint of a PED. However, the economic value of building envelope retrofitting depends on various factors such as location, climate, and population density. Retrofitting may be more cost-effective in warmer climates with low electricity tariffs.
#
# Overall, building envelope retrofitting plays a crucial role in achieving positive energy balances in PEDs and reducing energy demand and emissions. By combining active and passive retrofitting measures tailored to the specific needs of each building, it is possible to create more sustainable and energy-efficient environments in PEDs.
#
# Relevant Passages:
# ...
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.69): Question: what are the challenges with multi stakeholder engagement Answer: challenges found closely linked stakeholder engagement challenges found refs cost considerations smaller municipalities design firms may encounter difficulties affording advanced immersive positive_energy_district design tools need develop tailored software hardware interfaces type project current limitations available immersive technology terms usability response time user comfort e g field view ar platforms
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.67): central purpose stakeholder management engage targetusers facilitate dialogue stakeholder ensure diverse interests priorities taken consideration outlined fig characterization target users enables define adapt several aspects methodology positive_energy_district design review literature selection demonstrates activities aimed supporting cooperation among stakeholder usually included positive_energy_district design methodologies consequently absence structured framework stakeholder tend collaborate exchange
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.65): Question: what are the opportunities with multi stakeholder engagement Answer: opportunities collaborative design platforms facilitating participation multiple stakeholders positive_energy_district projects promise enhanced decision making consensus building virtual reality vr augmented reality ar technology offer immersive visualization positive_energy_district designs aiding stakeholders public comprehending engaging proposed projects co simulation collaborative platforms developed allow interactive
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.61): responsible community engagement single member able exercise decision making power organised results oriented manner community engagement limited members shareholders still include external stakeholder audited identify unseen needs solution enhance performance strategic area oversees prioritisation defines best practices reach objectives operates controlling power reports directly members operate retrospective analysis achieving defined objectives fulfilling rec mission vision monitored tactical area
#
# --------------------------------------------------
# Question: What are the differences between net zero energy building and positive energy district?
# Extractive Answer (BERT): question : what are the differences between net sero energy building and positive _ energy _ district answer : shift nearly net zero energy building nzebs nzebs positive _ energy _ district positive _ energy _ district signifies transition individual building energy _ efficiency district wide surplus energy _ generation management urban areas despite differences terms prioritize energy balance supply demand promoting site renewable _ energy generation research efforts pursuit nzeb zeb goals led studies focusing energy introduction basic principle positive _ energy _ district create area within city boundaries capable generating energy consumed agile flexible enough respond variation energy _ market positive _ energy _ district aim achieve annual surplus net energy another notion named net zero district urban area neighborhood total energy _ consumption equal energy produced specified period typically annually primary goal net zero district balance energy _ use production resulting net zero energy footprint unlike decarbonization process
# Generated Answer (GPT): The main differences between net zero energy building (NZEB) and positive energy district (PED) are as follows:
#
# 1. Scale: NZEB refers to an individual building that aims to achieve a balance between energy supply and demand, resulting in zero net energy consumption over a specified period, typically annually. On the other hand, PED encompasses a larger area within city boundaries, such as an urban district, that is capable of generating more energy than it consumes, leading to an annual surplus of net energy.
#
# 2. Focus: NZEB focuses on the energy performance of a single building, whereas PED focuses on managing energy at a district-wide level, promoting renewable energy generation and energy efficiency measures across multiple buildings and infrastructure within the district.
#
# 3. Integration: PED involves the integration of various energy systems and urban planning strategies at the district scale, aiming to optimize energy generation, consumption, and distribution across the entire area. In contrast, NZEB primarily focuses on the energy performance of an individual building and may not consider the broader district-level energy dynamics.
#
# 4. Goals: The primary goal of NZEB is to achieve a balance between energy use and production at the building level, resulting in a net zero energy footprint. In contrast, PED aims to achieve an annual surplus of net energy at the district level, contributing to the overall energy transition and sustainability goals of the city or urban area.
#
# Overall, while NZEB focuses on the energy performance of individual buildings, PED represents a more comprehensive approach that extends to the district scale, promoting energy efficiency, renewable energy generation, and overall energy balance within urban areas.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.73): Question: what are the differences between net sero energy building and positive_energy_district Answer: shift nearly net zero energy building nzebs nzebs positive_energy_district positive_energy_district signifies transition individual building energy_efficiency district wide surplus energy_generation management urban areas despite differences terms prioritize energy balance supply demand promoting site renewable_energy generation research efforts pursuit nzeb zeb goals led studies focusing energy
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.71): introduction basic principle positive_energy_district create area within city boundaries capable generating energy consumed agile flexible enough respond variation energy_market positive_energy_district aim achieve annual surplus net energy another notion named net zero district urban area neighborhood total energy_consumption equal energy produced specified period typically annually primary goal net zero district balance energy_use production resulting net zero energy footprint unlike
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.69): decarbonization process positive_energy_district concept developed previous ideas nearly net positive zero energy building extending single building district scale order exploit energy mutuality building urban decarbonization need broaden perspective arises several key aspects improvements single building approach example district approaches could offer benefits terms energy_system design integration terms striving towards optimized urban morphology district scale energy_system could offer economical
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.67): positive_energy_district integrates main paradigms smart sustainable city incrementally introduced integrated energy planning many city communities coming years suggested renovation wave
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.67): positive_energy_district highly ambitious neighbourhood concepts energy_efficiency local renewable generation two essential pillars achieving annual positive energy_balance net zero carbon emissions dynamic positive_energy_district constrained district borders therefore limited local generation potential low energy_consumption important importance passive retrofitting discussed positive_energy_district yet section literature review focuses concepts share aspects positive_energy_district extent considered
#
# --------------------------------------------------
# Question: How do different scales and evaluation boundaries affect positive energy district analysis?
# Extractive Answer (BERT): question : how different scales and evaluation boundaries are changing the analytical perspective of positive _ energy _ district answer : researchers involved different projects initiative engaged defining scales boundaries positive _ energy _ district help municipalities planners stakeholders exploit potential although discussion ongoing broad consensus upscaling building district scale mere sum single building methods requirements one hand aggregations building allow efficient management energy _ supply demand hand tenets together positive _ energy _ district guiding principles pillars presented prior section paper methodology followed results discussion section interview data presented discussed context existing research followed conclusions comprehensive pre evaluation entire city administrative district emerge suitable spatial scale analysis choice aims balance meaningful evaluation criteria practicality data collection facilitating assessment positive _ energy _ district achievability rather determining whether district positive _ energy _ district primary aim paper provide nuanced understanding positive _ energy _ district assessment schemes work different comparable types district purpose understand interrelationships assessment structure characteristics district energetic behaviour approach ensures comprehensive evaluation background focusing practical application assessment
# Generated Answer (GPT): Different scales and evaluation boundaries can significantly impact the analysis of positive energy districts. When considering different scales, such as building level, district level, or city level, the perspective of the analysis shifts in terms of the scope of impact and the level of detail in the assessment.
#
# At the building level, the focus is on individual energy efficiency measures and renewable energy integration within a single building. This scale allows for a detailed analysis of specific energy performance indicators and technology implementation.
#
# Moving to the district level, the analysis expands to consider the interactions between multiple buildings, energy systems, and infrastructure within a defined area. This scale enables a more holistic approach to energy management, including district heating and cooling systems, energy sharing mechanisms, and optimization strategies across multiple buildings.
#
# At the city level, the analysis encompasses an even broader perspective, considering the interactions between various districts, neighborhoods, and city-wide energy infrastructure. This scale allows for strategic planning and policy development to achieve energy sustainability goals at a larger urban scale.
#
# Evaluation boundaries also play a crucial role in positive energy district analysis. By defining the boundaries of the assessment, researchers can establish the scope of the analysis and determine which elements are included or excluded from the evaluation. This helps to ensure a consistent and meaningful comparison between different projects or initiatives.
#
# Overall, the choice of scale and evaluation boundaries in positive energy district analysis can impact the depth of understanding, the feasibility of implementation, and the overall effectiveness of energy efficiency measures and renewable energy integration within urban areas. Researchers, municipalities, planners, and stakeholders must carefully consider these factors to optimize the potential benefits of positive energy districts and achieve sustainable energy goals.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.83): Question: how different scales and evaluation boundaries are changing the analytical perspective of positive_energy_district Answer: researchers involved different projects initiative engaged defining scales boundaries positive_energy_district help municipalities planners stakeholders exploit potential although discussion ongoing broad consensus upscaling building district scale mere sum single building methods requirements one hand aggregations building allow efficient management energy_supply demand hand
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.74): tenets together positive_energy_district guiding principles pillars presented prior section paper methodology followed results discussion section interview data presented discussed context existing research followed conclusions
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.74): comprehensive pre evaluation entire city administrative district emerge suitable spatial scale analysis choice aims balance meaningful evaluation criteria practicality data collection facilitating assessment positive_energy_district achievability
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.73): rather determining whether district positive_energy_district primary aim paper provide nuanced understanding positive_energy_district assessment schemes work different comparable types district purpose understand interrelationships assessment structure characteristics district energetic behaviour approach ensures comprehensive evaluation background focusing practical application assessment methodologies within varied well understood district context first results application methodology presented
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.73): subsequently results evaluated firstly terms general applicability positive_energy_district assessment secondly related three positive_energy_district functions presented reference made results dena study concerning benefits integrated optimisation energy_system energy sharing district level positive_energy_district subsequently findings evaluation three methodologies discussed derive recommendations development general positive_energy_district framework
#
# --------------------------------------------------
# Question: What is involved in the planning of positive energy districts?
# Extractive Answer (BERT): positive _ energy _ district project positive _ energy _ district development project
# Generated Answer (GPT): Planning for positive energy districts involves a comprehensive approach that considers various aspects such as social, economic, energy, environmental, and societal goals. This includes analyzing data, creating strategies, and making decisions that will enable the development of districts that generate more renewable energy than they consume. Decision makers must be guided by analytical tools and insights to ensure that the project unfolds successfully and achieves its objectives. By considering all these factors at an early stage, the positive energy district project can advance effectively and serve as a model for sustainable urban development.
#
# Relevant Passages:
# Passage 1 (Parent Section: Chunks, Section: Chunks, Similarity: 0.81): positive_energy_district project
#
# Passage 2 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): positive_energy_district development project unfolds well level advance attains considering serve analytical guide decision makers best enable positive_energy_district
#
# Passage 3 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): positive_energy_district
#
# Passage 4 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): positive_energy_district
#
# Passage 5 (Parent Section: Chunks, Section: Chunks, Similarity: 0.77): positive_energy_district could impact social economic energy environmental societal goals
#
# --------------------------------------------------
# Question: What is the habitat of Polar Bears?
# No relevant answer.
# --------------------------------------------------
